# %%
# Magnesium antacids
antacid_A02AA_codes = [
  '29155',    # magnesium carbonate
  '6581',     # magnesium hydroxide
  '6582',     # magnesium oxide
  '1666106',  # magnesium peroxide
  '1310566'   # magnesium silicate
]

# Aluminium antacids
antacid_A02AB_codes = [
  '17392',  # aloglutamol
  '612',    # aluminum hydroxide
  '17618'   # aluminum phosphate
]

# Calcium antacids
antacid_A02AC_codes = [
  '1897',     # calcium carbonate
  '1311526'   # calcium silicate
]

antacid_codes = antacid_A02AA_codes + antacid_A02AB_codes + antacid_A02AC_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# H2-receptor antagonists
peptic_ulcer_gerd_A02BA_codes = [
  '2541',    # cimetidine
  '4278',    # famotidine
  '42319',   # nizatidine
  '9143',    # ranitidine
  '114817'   # roxatidine
]

# Proton pump inhibitors
peptic_ulcer_gerd_A02BC_codes = [
  '816346',  # dexlansoprazole
  '283742',  # esomeprazole
  '17128',   # lansoprazole
  '7646',    # omeprazole
  '40790',   # pantoprazole
  '114979'   # rabeprazole
]

# Other drugs for peptic ulcer and gastro-oesophageal reflux disease (GORD)
peptic_ulcer_gerd_A02BX_codes = [
  '16784',   # acetoxolone
  '17305',   # alginic acid
  '47181',   # bismuth subcitrate
  '19477',   # bismuth subnitrate
  '2017',    # carbenoxolone
  '8352',    # pirenzepine
  '8730',    # proglumide
  '10156'    # sucralfate
]

peptic_ulcer_gerd_codes = peptic_ulcer_gerd_A02BA_codes + peptic_ulcer_gerd_A02BC_codes + peptic_ulcer_gerd_A02BX_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
adrenergic_dopaminergic_codes = [
  '61609',    # arbutamine
  '47589',    # cafedrine
  '3616',     # dobutamine
  '3628',     # dopamine
  '23638',    # dopexamine
  '1489913',  # droxidopa
  '3966',     # ephedrine
  '3992',     # epinephrine
  '4169',     # etilefrine
  '24853',    # fenoldopam
  '41157',    # gepefrine
  '51253',    # ibopamine
  '6054',     # isoproterenol
  '6756',     # mephentermine
  '6805',     # metaraminol
  '6853',     # methoxamine
  '6963',     # midodrine
  '7512',     # norepinephrine
  '31988',    # norfenefrine
  '1311141',  # octopamine
  '8163',     # phenylephrine
  '31958'     # theodrenaline
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Antiadrenergic agents, centrally acting
antihypertensive_C02A_codes = [
  '2599',    # clonidine
  '62174',   # deserpidine
  '40114',   # guanfacine
  '235829',  # methoserpidine
  '6876',    # methyldopa
  '30257',   # moxonidine
  '9259',    # rescinnamine
  '9260',    # reserpine
  '55679'    # rilmenidine
]

# Antiadrenergic agents, ganglion-blocking
antihypertensive_C02B_codes = [
  '6673',  # mecamylamine
  '10828'  # trimethaphan
]

# Antiadrenergic agents, peripherally acting
antihypertensive_C02C_codes = [
  '1523',   # bethanidine
  '3118',   # debrisoquin
  '49276',  # doxazosin
  '5036',   # guanethidine
  '5784',   # indoramin
  '8629',   # prazosin
  '39230'   # urapidil
]

# Agents acting on arteriolar smooth muscle
antihypertensive_C02D_codes = [
  '3327',  # diazoxide
  '3409',  # dihydralazine
  '5470',  # hydralazine
  '6984',  # minoxidil
  '7476',  # nitroprusside
  '33717'  # pinacidil
]

# Other antihypertensives
antihypertensive_C02K_codes = [
  '358274',   # ambrisentan
  '75207',    # bosentan
  '6131',     # ketanserin
  '1442132',  # macitentan
  '266604',   # metyrosine
  '7930',     # pargyline
  '1439816'   # riociguat
]

antihypertensive_codes = antihypertensive_C02A_codes + antihypertensive_C02B_codes + antihypertensive_C02C_codes + antihypertensive_C02D_codes + antihypertensive_C02K_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
## Aldose reductase inhibitor
#Aldose_reductase_inhibitor_codes = [
#  '38386',  #tolrestat
#]

## Alpha-glucosidase-inhibitors
Alpha_glucodidase_inhibitors_codes = [
  '16681',  #acarbose
  '30009',  #miglitol
]

## Biguanides
Biguanides_codes = [
'6809',  #metformin
]

# Dipeptidyl peptidase-4 (DPP-4) inhibitors
DPP_4_codes = [
'1368001',   #alogliptin
'1100699',   #linagliptin
'857974',    #saxagliptin
'593411',    #sitagliptin
]

#Glucagon-like peptide-1 receptor agonist (GLP-1 receptor agonists)
GLP_1_receptor_agonists_codes  = [
'1534763',  #albiglutide
'1551291',  #dulaglutide
'60548',    #exenatide
'475968',   #liraglutide
'1440051',  #lixisenatide
'1991302',  #semaglutide
]

#Sodium-glucose transporters (SGLT) 2 inhibitors
SGLT_2_codes = [
'1373458',   #canagliflozin
'1488564',   #dapagliflozin
'1545653',   #empagliflozin
'1992672',   #ertugliflozin
]

#Sulfonylureas
Sulfonylureas_codes = [
'2404',   #chlorpropamide
'102846',  #glibornuride
'4816',   #gliclazide
'25789' , #glimepiride
'4821',    #glipizide
'25793',   #gliquidone
'4815',    #glyburide
'217364',   #glyburide, micronized
'10635',   #tolbutamide
]

#Thiazolidinediones 
Thiazolidinediones_codes = [
'33738',   #pioglitazone
'84108',   #rosiglitazone
]

#Other blood glucose lowering drugs
Other_lowering_blood_glucose_drugs_codes = [
'26344',   #guar gum
'274332',  #nateglinide
'139953',  #pramlintide
'73044',   #repaglinide
]

#Combination of oral drugs
combo_oral_Antidiabetic_drugs_codes = [
'1368384',   #alogliptin / metformin
'1368402',   #alogliptin / pioglitazone
'1545149',   #canagliflozin / metformin
'1486436',   #dapagliflozin / metformin
'2117292',   #dapagliflozin / metformin / saxagliptin
'1727500',   #dapagliflozin / saxagliptin
'1598392',   #empagliflozin / linagliptin
'2281864',   #empagliflozin / linagliptin / metformin
'1664314',   #empagliflozin / metformin
'1992684',   #ertugliflozin / metformin
'1992825',   #ertugliflozin / sitagliptin
'647235',    #glimepiride / pioglitazone
'606253',    #glimepiride / rosiglitazone
'352381',    #glipizide/metformin
'285129',    #glyburide/metformin
'1243019',   #linagliptin / metformin
'607999',    #metformin / pioglitazone
'802646',    #metformin / repaglinide
'614348',    #metformin / rosiglitazone
'1043562',   #metformin / saxagliptin
'729717',    #metformin / sitagliptin
]

#Insulin
Insulin_codes = [
'51428',    #insulin aspart, human
'1670007',  #insulin degludec
'1727493',  #insulin degludec / liraglutide
'139825',   #insulin detemir
'274783',   #insulin glargine
'1858994',  #insulin glargine / lixisenatide
'400008',   #insulin glulisine, human
'86009',    #insulin lispro
'253182',   #insulin, regular, human
]

#All antidiabetic medication: 
diabetes_medication_codes = Alpha_glucodidase_inhibitors_codes + Biguanides_codes + DPP_4_codes + GLP_1_receptor_agonists_codes + SGLT_2_codes + Sulfonylureas_codes + Thiazolidinediones_codes +\
Other_lowering_blood_glucose_drugs_codes + combo_oral_Antidiabetic_drugs_codes + Insulin_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
beta_blocker_codes = [
  '149',    # acebutolol
  '597',    # alprenolol
  '1202',   # atenolol
  '1520',   # betaxolol
  '19484',  # bisoprolol
  '19605',  # bopindolol
  '1817',   # bupranolol
  '2116',   # carteolol
  '20352',  # carvedilol
  '20498',  # celiprolol
  '49737',  # esmolol
  '6185',   # labetalol
  '29518',  # mepindolol
  '6918',   # metoprolol
  '7226',   # nadolol
  '31555',  # nebivolol
  '7801',   # oxprenolol
  '7973',   # penbutolol
  '8332',   # pindolol
  '8620',   # practolol
  '8787',   # propranolol
  '9947',   # sotalol
  '37546',  # talinolol
  '37840',  # tertatolol
  '10600'   # timolol
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Selective calcium channel blockers with mainly vascular effects
calcium_channel_blocker_C08C_codes = [
  '17767',   # amlodipine
  '233603',  # clevidipine
  '4316',    # felodipine
  '33910',   # isradipine
  '28382',   # lacidipine
  '135056',  # lercanidipine
  '29275',   # manidipine
  '39879',   # mepirodipine
  '83213',   # mibefradil
  '7396',    # nicardipine
  '7417',    # nifedipine
  '53692',   # nilvadipine
  '7426',    # nimodipine
  '7435',    # nisoldipine
  '7441'     # nitrendipine
]

# Selective calcium channel blockers with direct cardiac effects
calcium_channel_blocker_C08D_codes = [
  '3443',  # diltiazem
  '4648',  # gallopamil
  '11170'  # verapamil
]

# Non-selective calcium channel blockers
calcium_channel_blocker_C08E_codes = [
  '1436',   # bepridil
  '4327',   # fendiline
  '6390',   # lidoflazine
  '8050'    # perhexiline
]

calcium_channel_blocker_codes = calcium_channel_blocker_C08C_codes + calcium_channel_blocker_C08D_codes + calcium_channel_blocker_C08E_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# ACE inhibitors, plain
renin_angiotensin_C09A_codes = [
  '18867',  # benazepril
  '1998',   # captopril
  '21102',  # cilazapril
  '3827',   # enalapril
  '50166',  # fosinopril
  '60245',  # imidapril
  '29046',  # lisinopril
  '30131',  # moexipril
  '54552',  # perindopril
  '35208',  # quinapril
  '35296',  # ramipril
  '36908',  # spirapril
  '38454',  # trandolapril
  '39990'   # zofenopril
]

# Angiotensin II receptor blockers (ARBs)
renin_angiotensin_C09C_codes = [
  '1091643',  # azilsartan
  '214354',   # candesartan
  '83515',    # eprosartan
  '83818',    # irbesartan
  '52175',    # losartan
  '321064',   # olmesartan
  '73494',    # telmisartan
  '69749'     # valsartan
]

# Other agents acting on the renin-angiotensin system
renin_angiotensin_C09X_codes = [
  '325646'   # aliskiren
]

renin_angiotensin_codes = renin_angiotensin_C09A_codes + renin_angiotensin_C09C_codes + renin_angiotensin_C09X_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Non-selective monoamine reuptake inhibitors
antidepressant_N06AA_codes = [
  '17698',    # amineptin
  '704',      # amitriptyline
  '722',      # amoxapine
  '19895',    # butriptyline
  '2597',     # clomipramine
  '3247',     # desipramine
  '3332',     # dibenzepin
  '3634',     # dothiepin
  '3638',     # doxepin
  '5691',     # imipramine
  '5979',     # iprindole
  '6465',     # lofepramine
  '6646',     # maprotiline
  '446248',   # melitracen
  '7531',     # nortriptyline
  '7674',     # opipramol
  '8886',     # protriptyline
  '35242',    # quinupramine
  '10834'     # trimipramine
]

# Selective serotonin reuptake inhibitors
antidepressant_N06AB_codes = [
  '2556',     # citalopram
  '321988',   # escitalopram
  '4493',     # fluoxetine
  '42355',    # fluvoxamine
  '32937',    # paroxetine
  '36437'     # sertraline
]

# Monoamine oxidase inhibitors, non-selective
antidepressant_N06AF_codes = [
  '6011',   # isocarboxazid
  '7394',   # nialamide
  '8123',   # phenelzine
  '10734'   # tranylcypromine
]

# Monoamine oxidase A inhibitors
antidepressant_N06AG_codes = [
  '30121',   # moclobemide
  '38382'    # toloxatone
]

# Monoamine oxidase B inhibitors (add this for antidepressant?)
# '9639'  # selegiline

# Other antidepressants
antidepressant_N06AX_codes = [
  '94',        # 5-hydroxytryptophan
  '47111',     # bifemelane
  '42347',     # bupropion
  '734064',    # desvenlafaxine
  '72625',     # duloxetine
  '2119365',   # esketamine
  '29434',     # medifoxamine
  '6929',      # mianserin
  '588250',    # milnacipran
  '30031',     # minaprine
  '15996',     # mirtazapine
  '31565',     # nefazodone
  '7500',      # nomifensine
  '60842',     # reboxetine
  '258326',    # St. John's wort extract
  '38252',     # tianeptine
  '10737',     # trazodone
  '10898',     # tryptophan
  '39786',     # venlafaxine
  '1086769',   # vilazodone
  '11196',     # viloxazine
  '1455099'    # vortioxetine
]
# '1433212',  # levomilnacipran (no ATC in RxNav)

antidepressant_codes = antidepressant_N06AA_codes + antidepressant_N06AB_codes + antidepressant_N06AF_codes + antidepressant_N06AG_codes + antidepressant_N06AX_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
siponimod_codes = ['2121085', # siponimod 
                  ]
ponesimod_codes = ['2532300', # ponesimod
                  ]
fingolimod_codes = ['1012892', # fingolimod
                   ]
ozanimod_codes = ['2288236', # ozanimod
                ]
S1P_receptor_modulators_codes = siponimod_codes  + ponesimod_codes  + fingolimod_codes + ozanimod_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
vasopressor_codes = [
  '3616',   # dobutamine
  '3628',   # dopamine
  '3966',   # ephedrine
  '3992',   # epinephrine
  '6963',   # midodrine
  '7512',   # norepinephrine
  '8163',   # phenylephrine
  '11149'   # vasopressin (USP)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Notice: The following are added without medical review!!!

# %%
remdesivir_codes = [
  '2284718',   # remdesivir
  '2395498',   # Brand name: Veklury
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cobicistat_codes = [
  '1306284',   # cobicistat
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
emtricitabine_codes = [
  '276237',   # emtricitabine
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
tenofovir_codes = [
  '117466',   # tenofovir
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
efavirenz_codes = [
  '195085',   # efavirenz
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
bictegravir_codes = [
  '1999660',   # bictegravir
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rilpivirine_codes = [
  '1102270',   # rilpivirine
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
csDMARDs_codes = [
  '1256',      # azathioprine
  '3002',          # cyclophosphamide
  '5521',          # hydroxychloroquine
  '27169',          # leflunomide
  '1310520',      # teriflunomide
  '103',          # mercaptopurine
  '6851',          # methotrexate
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mycophenolate_codes = [
  '265323',          # mycophenolate
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
azathioprine_codes = ['1256',     # azathioprine
                   ]
cyclophosphamide_codes = ['3002',          # cyclophosphamide
                       ]

hydroxychloroquine_codes = ['5521',          # hydroxychloroquine
                           ]
leflunomide_codes = ['27169',          # leflunomide
                     ]
teriflunomide_codes = ['1310520', # teriflunomide
                      ]
mercaptopurine_codes = ['103',          # mercaptopurine
                        ]
methotrexate_codes = ['6851',          # methotrexate
                     ]

# 5-asa
balsalazide_codes = ['18747',  # balsalazide
                   ]
                    
sulfasalazine_codes = ['9524',   # sulfaSALAzine
                     ]
mesalamine_codes = ['52582',  # mesalamine
                  ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
steroids_codes = [
  '3264',   # dexamethasone
  '5492',   # hydrocortisone
  '8638',   # prednisoLONE
  '6902',   # methylPREDNISolone
  '8640',   # predniSONE
  '10759', # triamcinolone
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
prednisolone_codes = ['8638',   # prednisoLONE
                     ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
hydrocortisone_codes = ['5492',   # hydrocortisone
                       ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
  dexamethasone_codes = ['3264',   # dexamethasone
                        ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
triamcinolone_codes = ['10759', #triamcinolone
                      ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
methylprednisolone_codes = ['6902',   # methylPREDNISolone
                          ]
prednisone_codes = ['8640',   # predniSONE
                  ]

budesonide_codes = [
  '19831',  # budesonide
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
VASA_codes = [
  '18747',  # balsalazide
  '9524',   # sulfasalazine
  '52582',  # mesalamine
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
JAKi_codes = [
  '1357536',  # tofacitinib
  '2196092',  # upadacitinib
  '2047232',  # baricitinib
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
tofacitinib_codes = ['1357536',  # tofacitinib
                   ]
upadacitinib_codes = ['2196092',  # upadacitinib
                    ]
baricitinib_codes = ['2047232',  # baricitinib
                   ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Calcineurin_inhibitor_codes = [
  '3008',  # cyclosporine
  '35302', # sirolimus
  '42316', # tacrolimus
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sirolimus_codes =  ['35302', # sirolimus
                  ]
tacrolimus_codes = [ '42316', # tacrolimus
                  ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
TNF_inhibitor_codes = [
  '327361', # adalimumab
  '709271', # certolizumab pegol
  '214555', # etanercept
  '819300', # golimumab
  '191831', # infliximab
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
adalimumab_codes = ['327361', # adalimumab
                  ]
certolizumab_pegol_codes = ['709271', # certolizumab pegol
                            ]
etanercept_codes = ['214555', # etanercept
                  ]
golimumab_codes  = ['819300', # golimumab
                ]
infliximab_codes = ['191831', # inFLIXimab
                  ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
canakinumab_codes = [
  '853491', # canakinumab
]

anakinra_codes = [
  '72435', # anakinra
]

rilonacept_codes = [
  '763450', # rilonacept
]

IL1_inhibitor_codes = canakinumab_codes + anakinra_codes + rilonacept_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sarilumab_codes = ['1923319',  # sarilumab
                 ]
tocilizumab_codes = ['612865',   # tocilizumab
                   ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
IL6_inhibitor_codes = [
  '1923319',  # sarilumab
  '612865',   # tocilizumab
  '2391541'  ,# satralizumab
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
satralizumab_codes = ['2391541'  ,# satralizumab
                     ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
IL12_23_inhibitor_codes = [
  '847083', # ustekinumab 
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ustekinumab_codes= ['847083', # ustekinumab
                  ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
IL17_inhibitor_codes = [
  '1745099',  # ixekizumab
  '1872251',  # brodalumab
  '1599788',  # secukinumab
  
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ixekizumab_codes = ['1745099',  # ixekizumab
                  ]
brodalumab_codes = ['1872251',  # brodalumab
                  ]
secukinumab_codes = ['1599788',  # secukinumab
                   ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
IL23_inhibitor_codes = [
  '1928588',  # guselkumab
  '2053436',  # tildrakizumab
  '2166040',  # risankizumab
  
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
guselkumab_codes = ['1928588',  # guselkumab
                  ]
tildrakizumab_codes =  ['2053436',  # tildrakizumab
                      ]
risankizumab_codes = ['2166040',  # risankizumab
                    ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rituximab_codes = [
  '121191', # rituximab
  
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
belimumab_codes = [
  '1092437', # belimumab, anti-BLyS
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Tcell_modulator_codes = [
  '614391', # abatacept
  
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
abatacept_codes = ['614391', # abatacept
                 ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Integrin_modulator_codes = [
  '1538097',  # vedolizumab
  '354770',  # natalizumab
  
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
vedolizumab_codes = ['1538097',  # vedolizumab
                   ]
natalizumab_codes =  ['354770',  # natalizumab
                    ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
PDE4i_targeted_synthetic_codes = [
  '1492727', # apremilast
  
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
apremilast_codes = ['1492727', # apremilast
                  ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Nirmatrelvir_codes = [
  '2587892', # nirmatrelvir
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
Molnupiravir_codes = [
  '2587901', # molnupiravir
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ocrelizumab_code = ['1876366', #ocrelizumab
                   ]
ofatumumab_codes = ['712566', #ofatumumab
                   ]
cd20_codes = ocrelizumab_code + ofatumumab_codes + rituximab_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
alemtuzumab_codes = ['117055', #alemtuzumab
                    ]
CD52_codes = alemtuzumab_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cladribine_codes  = ['44157', # cladribine
                   ]
purine_antimetabolite_codes = cladribine_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
interferon_beta_1a_codes =  ['75917', #Interferon beta-1a
                            ]
interferon_beta_1b_codes = ['72257', #interferon_beta-1b
                            ]
interferons_codes = interferon_beta_1a_codes + interferon_beta_1b_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mitoxantrone_codes = ['7005', #mitoxantrone
               ]
anthracenediones_codes = mitoxantrone_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cyclosporine_codes = ['3008', #cyclosporine
                     ]
IL2_inhibitor_codes = cyclosporine_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
chlorambucil_codes = ['2346', #chlorambucil
                     ]
alkylating_codes = chlorambucil_codes + cyclophosphamide_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# chlorambucil_codes = ['2346', # chlorambucil
#                      ]
# alkylating_codes = chlorambucil_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
colchicine_codes = ['2683', #colchicine
                   ]
β_tubulin_polymerization_inhibitor_codes = colchicine_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dapsone_codes = ['3108', #dapsone
]
PABA_antagonist_codes = dapsone_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
hydroxyurea_codes = ['5552', #hydroxyurea
                    ]
rNDP_inhibitor_codes = hydroxyurea_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dimethyl_fumarate_codes = ['1373478', #dimethyl fumarate
                          ]
diroximel_fumarate_codes = ['2261783',  #diroximel fumarate
                           ]
monomethyl_fumarate_codes = ['1546433', #monomethyl fumarate
                            ]
fumarates_codes = dimethyl_fumarate_codes + diroximel_fumarate_codes + monomethyl_fumarate_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ursodiol_codes = ['11065',  #ursodiol
                 ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cholestyramine_codes = ['2447',  #cholestyramine
                     ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
metformin_codes = ['6809', #metformin
                  ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ursodeoxycholic_acid_codes = ['11065', #Ursodeoxycholic acid
                             ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
vancomycin_codes = ['11124', #Vancomycin
                   ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
azathioprine_codes = ['1256', #Azathioprine
                     ]
mercaptopurine_codes = ['103', #mercaptopurine
                         ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
tacrolimus_codes = ['42316', #Tacrolimus
                   ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dpenicillamine_codes = ['7975', #d-penicillamine
                        ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
etanercept_codes = ['214555', #Etanercept
                   ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
## Monoclonal Antibody
## COVID-19 related
monoclonal_antibody_covid_19_codes = [
  '2463114',    # bamlanivimab
  '2592360',    # bebtelovimab
  '2465242',	# casirivimab
  '2587306',	# cilgavimab
  '2477854', 	# etesevimab
  '2465249',	# imdevimab
  '2550731',	# sotrovimab
  '2587300',	# tixagevimab
  #'2387211',	# tafasitamab, use for both COVID-19, large B-cell lymphoma, so included in both sides 
]

monoclonal_antibody_covid_19_Omicron_codes = [
  #'2463114',    # bamlanivimab
  '2592360',    # bebtelovimab
  #'2465242',	# casirivimab
  '2587306',	# cilgavimab
  #'2477854', 	# etesevimab
#   '2465249',	# imdevimab
#   '2550731',	# sotrovimab
  '2587300',	# tixagevimab
]

# ## Other usage
# monoclonal_antibody_other_usage_codes = [
#   '117055',	 # alemtuzumab
#   '712566',  # ofatumumab
#   '2387211',	# tafasitamab, use for both COVID-19, large B-cell lymphoma, so included in both sides
#   '2540964',	# loncastuximab tesirine
#   '1721947', 	# daratumumab
#   '1721952',	# darzalex
#   '1726104', 	# elotuzumab
#   '2282019',	# isatuximab-irfc
#   '190353',	 # daclizumab
#   '1876366',	# ocrelizumab
#   '121191',	# rituximab
#   '612865', #tocilizumab
#   '1092437', # belimumab (yes this is immunosuppressant, JDG)
# ]
  
# ## General (COVID-19 + Other usage)
# monoclonal_antibody_codes = monoclonal_antibody_covid_19_codes + monoclonal_antibody_other_usage_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
## palbociclib
palbociclib_codes = [
  '1601374'
]

ribociclib_codes = [
  '1873916'
]

abemaciclib_codes = [
  '1946825'
]

CDK_4_6_inhibitor_codes = palbociclib_codes + ribociclib_codes + abemaciclib_codes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
medications_cc_registry = {
  ## A02A: Antacids
  'antacid': antacid_codes,
  'antacid_A02AA': antacid_A02AA_codes,  # Magnesium compounds
  'antacid_A02AB': antacid_A02AB_codes,  # Aluminium compounds
  'antacid_A02AC': antacid_A02AC_codes,  # Calcium compounds
  
  ## A02B: Drugs for peptic ulcer and gastroesophageal reflux disease (GERD)
  'peptic_ulcer_gerd': peptic_ulcer_gerd_codes,
  'peptic_ulcer_gerd_A02BA': peptic_ulcer_gerd_A02BA_codes,  # H2-receptor antagonists
  'peptic_ulcer_gerd_A02BC': peptic_ulcer_gerd_A02BC_codes,  # Proton pump inhibitors
  'peptic_ulcer_gerd_A02BX': peptic_ulcer_gerd_A02BX_codes,  # Other drugs for peptic ulcer and (GERD)
  
  ## C01CA: Adrenergic and dopaminergic agents
  'adrenergic_dopaminergic': adrenergic_dopaminergic_codes,
  
  ## C02: Antihypertensives
  'antihypertensive': antihypertensive_codes,
  'antihypertensive_C02A': antihypertensive_C02A_codes,  # Antiadrenergic agents, centrally acting
  'antihypertensive_C02B': antihypertensive_C02B_codes,  # Antiadrenergic agents, ganglion-blocking
  'antihypertensive_C02C': antihypertensive_C02C_codes,  # Antiadrenergic agents, peripherally acting
  'antihypertensive_C02D': antihypertensive_C02D_codes,  # Agents acting on arteriolar smooth muscle
  'antihypertensive_C02K': antihypertensive_C02K_codes,  # Other antihypertensives
  
  ## C07A: Beta blocking agents
  'beta_blocker': beta_blocker_codes,
  
  ## C08: Calcium channel blockers
  'calcium_channel_blocker': calcium_channel_blocker_codes,
  'calcium_channel_blocker_C08C': calcium_channel_blocker_C08C_codes,  # Selective calcium channel blockers with mainly vascular effects
  'calcium_channel_blocker_C08D': calcium_channel_blocker_C08D_codes,  # Selective calcium channel blockers with direct cardiac effects
  'calcium_channel_blocker_C08E': calcium_channel_blocker_C08E_codes,  # Non-selective calcium channel blockers
  
  ## C09: Agents acting on the renin-angiotensin system
  'renin_angiotensin': renin_angiotensin_codes,
  'renin_angiotensin_C09A': renin_angiotensin_C09A_codes,  # ACE inhibitors, plain
  'renin_angiotensin_C09C': renin_angiotensin_C09C_codes,  # Angiotensin II receptor blockers (ARBs)
  'renin_angiotensin_C09X': renin_angiotensin_C09X_codes,  # Other agents acting on the renin-angiotensin system
  
  ## N06: Antidepressants

  'antidepressant': antidepressant_codes,
  'antidepressant_N06AA': antidepressant_N06AA_codes,  # Non-selective monoamine reuptake inhibitors
  'antidepressant_N06AB': antidepressant_N06AB_codes,  # Selective serotonin reuptake inhibitors
  'antidepressant_N06AF': antidepressant_N06AF_codes,  # Monoamine oxidase inhibitors, non-selective
  'antidepressant_N06AG': antidepressant_N06AG_codes,  # Monoamine oxidase A inhibitors
  'antidepressant_N06AX': antidepressant_N06AX_codes,  # Other antidepressants
    
  'vasopressor': vasopressor_codes,
  'prednisone': prednisone_codes,
  ## Added without medical review
  'remdesivir': remdesivir_codes,
  'cobicistat': cobicistat_codes,
  'emtricitabine': emtricitabine_codes,
  'tenofovir': tenofovir_codes,
  'efavirenz': efavirenz_codes,
  'bictegravir': bictegravir_codes,
  'rilpivirine': rilpivirine_codes,
  'csDMARDs' : csDMARDs_codes,
  'mycophenolate' : mycophenolate_codes,
  'steroids' : steroids_codes,
  'triamcinolone': triamcinolone_codes,
  'Five_ASA' : VASA_codes,
  'JAKi' : JAKi_codes,
  'Calcineurin_inhibitor' : Calcineurin_inhibitor_codes,
  'TNF_inhibitor' : TNF_inhibitor_codes,
  'IL1_inhibitor' : IL1_inhibitor_codes,
  'IL6_inhibitor' : IL6_inhibitor_codes,
  'IL12_23_inhibitor' : IL12_23_inhibitor_codes,
  'IL17_inhibitor' : IL17_inhibitor_codes,
  'IL23_inhibitor' : IL23_inhibitor_codes,
  'rituximab' : rituximab_codes,
  'T_cell_modulator' : Tcell_modulator_codes,
  'Integrin_modulator' : Integrin_modulator_codes,
  'PDE4i_targeted_synthetic' : PDE4i_targeted_synthetic_codes,
  'Nirmatrelvir': Nirmatrelvir_codes,
  'Molnupiravir': Molnupiravir_codes,
## Others medication
  'azathioprine': azathioprine_codes,
  'cyclophosphamide': cyclophosphamide_codes, 
  'hydroxychloroquine': hydroxychloroquine_codes, 
  'leflunomide' : leflunomide_codes,
  'mercaptopurine': mercaptopurine_codes, 
  'methotrexate' : methotrexate_codes,
  'mycophenolate': mycophenolate_codes, 
  'balsalazide' :  balsalazide_codes, 
  'sulfasalazine' : sulfasalazine_codes,
  'mesalamine' : mesalamine_codes ,
  'sirolimus' : sirolimus_codes,
  'tacrolimus' : tacrolimus_codes, 
  'adalimumab': adalimumab_codes,
  'certolizumab_pegol' : certolizumab_pegol_codes, 
  'etanercept' :  etanercept_codes,
  'golimumab': golimumab_codes,
  'hydrocortisone':hydrocortisone_codes,
  'infliximab' : infliximab_codes,
  'sarilumab' : sarilumab_codes,
  'tocilizumab' : tocilizumab_codes, 
  'canakinumab' : canakinumab_codes,
  'ustekinumab' : ustekinumab_codes,
  'ixekizumab' : ixekizumab_codes, 
  'brodalumab' : brodalumab_codes,
  'secukinumab' : secukinumab_codes, 
  'guselkumab' : guselkumab_codes,
 'tildrakizumab' : tildrakizumab_codes, 
 'risankizumab': risankizumab_codes,
  'abatacept': abatacept_codes,
 'rituximab' : rituximab_codes, 
  'ozanimod' : ozanimod_codes, 
  'tofacitinib' : tofacitinib_codes,
  'upadacitinib' : upadacitinib_codes,
  'baricitinib' : baricitinib_codes,
  'vedolizumab' : vedolizumab_codes,
  'natalizumab' : natalizumab_codes,
  'apremilast' : apremilast_codes,
  'belimumab': belimumab_codes,
  'satralizumab': satralizumab_codes,
  'prednisolone': prednisolone_codes,
## S1P receptor modulators
  'siponimod': siponimod_codes,
  'ponesimod': ponesimod_codes, 
  'fingolimod': fingolimod_codes, 
  'S1P_receptor_modulators': S1P_receptor_modulators_codes,
  'dexamethasone':dexamethasone_codes ,
## CD20
 'ocrelizumab': ocrelizumab_code, 
 'ofatumumab': ofatumumab_codes, 
 'cd20': cd20_codes, 
## CD52
  'alemtuzumab': alemtuzumab_codes,
  'cd52': CD52_codes,
## pyrimidine synthesis inhibitors
 'teriflunomide': teriflunomide_codes,  
  # purine antimetabolite
  'cladribine': cladribine_codes, 
  'purine_antimetabolite': purine_antimetabolite_codes, 
## interferons
'interferon_beta_1a': interferon_beta_1a_codes, 
'interferon_beta_1b': interferon_beta_1b_codes, 
'interferons': interferons_codes, 
  
## mitoxantrone
'mitoxantrone':  mitoxantrone_codes,
'anthracenediones': anthracenediones_codes,
  
## IL-2 inhibitor
'cyclosporine': cyclosporine_codes, 
'IL2_inhibitor': IL2_inhibitor_codes,
  
## alkylating
'chlorambucil': chlorambucil_codes,
'alkylating': alkylating_codes,
  
## β-tubulin polymerization inhibiton
'colchicine': colchicine_codes,
'β_tubulin_polymerization_inhibitor': β_tubulin_polymerization_inhibitor_codes,
  
## PABA antagonist
'dapsone': dapsone_codes,
'PABA_antagonist': PABA_antagonist_codes,

## hydroxyurea_codes
'hydroxyurea': hydroxyurea_codes,
'rNDP_inhibitor': rNDP_inhibitor_codes,
  
## fumarates
'dimethyl_fumarate': dimethyl_fumarate_codes,
'diroximel_fumarate': diroximel_fumarate_codes,
'monomethyl_fumarate': monomethyl_fumarate_codes, 
'fumarates': fumarates_codes,
'methylprednisolone': methylprednisolone_codes,
## Monoclonal Antibody
## COVID-19 related
'monoclonal_antibody_covid_19': monoclonal_antibody_covid_19_codes,
'monoclonal_antibody_covid_19_Omicron': monoclonal_antibody_covid_19_Omicron_codes,
## Other usage
#'monoclonal_antibody_other_usage': monoclonal_antibody_other_usage_codes,
## General (COVID-19 + Other usage)
#'monoclonal_antibody': monoclonal_antibody_codes,
  
#others
'ursodiol': ursodiol_codes,
'cholestyramine': cholestyramine_codes,
'metformin': metformin_codes,
'ursodeoxycholic_acid': ursodeoxycholic_acid_codes, 

'methotrexate':methotrexate_codes,
'vancomycin': vancomycin_codes, 
'tacrolimus': tacrolimus_codes,
'dpenicillamine':dpenicillamine_codes,
'etanercept': etanercept_codes,
  
#All antidiabetic medication: 
'diabetes_medication': diabetes_medication_codes,
#'Aldose_reductase_inhibitor': Aldose_reductase_inhibitor_codes,  
'Alpha_glucodidase_inhibitors': Alpha_glucodidase_inhibitors_codes,
'Biguanides': Biguanides_codes,
'DPP_4': DPP_4_codes,
'GLP_1_receptor_agonists': GLP_1_receptor_agonists_codes,
'SGLT_2': SGLT_2_codes,
'Sulfonylureas': Sulfonylureas_codes,
'Thiazolidinediones': Thiazolidinediones_codes,
'Other_lowering_blood_glucose_drugs': Other_lowering_blood_glucose_drugs_codes,
'combo_oral_Antidiabetic_drugs': combo_oral_Antidiabetic_drugs_codes,
'Insulin': Insulin_codes,
  
'anakinra': anakinra_codes,
'rilonacept': rilonacept_codes,
'budesonide': budesonide_codes, 
## CDK 4/6 inhibitor class
'CDK_4_6_inhibitor': CDK_4_6_inhibitor_codes,
'palbociclib': palbociclib_codes,
'ribociclib': ribociclib_codes,
'abemaciclib': abemaciclib_codes,
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

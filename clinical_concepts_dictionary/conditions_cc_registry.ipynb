# %%
#### Patricia's note
abd_codes = [
  '21522001'     # Abdominal pain (finding)
]
#Very broad, includes all causes of abdominal pain
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
### detail friendly tips from Kathleen
acute_pulmonary_edema_codes = [
  '40541001'     # Acute pulmonary edema (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
### warning note from Patricia
### use meds as well
acute_renal_failure_codes = [
  '14669001'     # Acute renal failure syndrome (disorder)
]
#### Patricia's note:
# Also unknown as acute kidney failure. If extreme, consider dialysis (snomed#265764009), which includes hemodialysis and peritoneal dialysis). Labs related: BUN and creatinine
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ards_codes = [
  '67782005'     # Acute respiratory distress syndrome (disorder)
]
#### Patricia's note:
# If ARDS caused by COVID: snomed#674814021000119106
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
acute_respiratory_failure_codes = [
  '65710008'     # Acute respiratory failure (disorder)
]
#### Patricia's note:
# It's the failure to breathe and get oxygen. Very likely that the patient will need oxygen therapy
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
adrenal_insufficiency_codes = [
  '386584007'     # Acute respiratory failure (disorder)
]

#### :
# Low cortisol
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note:
anemia_codes = [
  '271737000'     # Anemia (disorder)
]
# Anemia is the decrease of hemoglobin or red blood cells. Labs: hemoblobin, hematocrit, reticulocytes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
aids_codes = [
  '62479008'     # AIDS (disorder)
]
# When the patient who carries HIV presents symptoms (immunodeficiency)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
alcoholism_codes = [
  '7200002'     # Alcoholism (disorder)
]
# Active alcoholism. Recommended to use with social history
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia'note
alzheimer_failure_codes = [
  '26929004'     # Alzheimer's disease (disorder)
]
# It's a kind of dementia (see below), usually presented in elderly
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
ankylosing_codes = [
  '9631008', # Ankylosing spondylitis (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Qi's note
#### verified
antiphospholipid_syndrome_codes = [
  '26843008', #Antiphospholipid syndrome (disorder)
  '72161000119100', #Antiphospholipid syndrome in pregnancy (disorder)
  '774084003', #Neonatal antiphospholipid syndrome (disorder)
  '239892009', #Primary antiphospholipid syndrome (disorder)
  '239895006', #Secondary antiphospholipid syndrome (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
appendectomy_codes = [
  '80146002', # Appendectomy (procedure)
]
# Surgery to remove appendix if appendicitis
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
appendicitis_codes = [
  '74400008', # Appencitis (disorder)
]
# Current status and not history of appendicitis
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
arthritis_codes = [
  '3723001'      # Arthritis (disorder)
]
#### Patricia's note:
# Arthritis is very broad. If degenerative or related to age, use osteoarthritis or osteoarthrosis (snomed#396275006). It can be infectious (snomed#26071001), auto-immune (rheumatoid arthritis, lupus, etc), gout, and reactive.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
arteriosclerotic_vascular_disease_codes = [
  '72092001'      # Arteriosclerotic vascular disease (disorder)
]
#### Patricia's note:
# Plaques of cholesterol inside the arteries. It can lead to myocardial infarction if affects heart arteries (see below), stroke if affects brain arteries, and poor circulation in limbs
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Patricia's note:
asplenia_codes = [
  '707147002'     # Asplenia (disorder)
]
## Spleen non-functional or removed
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
asthma_codes = [
  '195967001'      # Asthma (disorder)
]
#### Patricia's note
# Allergy table may be important for asthma
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
atrial_fibrillation_codes = [
  '49436004'      # Atrial fibrillation (disorder)
]
#### Patricia's note:
# Atrial fibrillation is a type of cardiac arrhythmia (see below)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
autoimmune_disease_noSjorgren_codes = [
  '85828009'      # Autoimmune disease codes (no Sjorgren)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
auto_hepatitis_codes = [
  '408335007'     # Auto-immune hepatitis (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
auto_enteropathy_codes = ['235728001', #Autoimmune enteropathy
                         ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
auto_pap_codes = ['707443007', #Autoimmune pulmonary alveolar proteinosis
                 ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Patricia's note:
bph_codes = [
  '59282003'     # Benign prostatic hyperplasia (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
bipolar_codes = [
  '13746004'     # Bipolar disorder (disorder)
]
# Includes all subtypes of bipolar disorder
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
bladder_cancer_codes = [
  '399326009'     # Bladder cancer (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
breast_codes = [
  '254837009'     # Malignant neoplasm of breast (disorder)
]
# Includes all types
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
blood_loss_codes = [
  '50960005'     # Hemorrhage (morphologic abnormality)
]
#### Patricia's note:
# It can be massive or oculte (not noticed)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cardiac_arrhythmia_codes = [
  '698247007'      # Cardiac arrhythmia (disorder)
]
#### Patricia's note:
# It means irregular heart beats. In this case, heart rate is usually too low (<60) or too high (>100).
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note:
crf_codes = [
  '410431009'     # Cardiorespiratory failure (disorder)
]
# When patient stops breathing and heart stops beating. Needs cardiopulmonary resuscitation (basic life support)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
cbd_codes = [
  '763662005'     # Cannabis oil (substance)
]
# CBD or medicinal cannabis use
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
cdfficile_codes = [
  '186431008'     # Clostridioides difficile infection (disorder)
]
# History of bariatric surgery (surgery to treat obesity)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cerebrovascular_accident_codes = [
  '230690007'     # Cerebrovascular accident (disorder)
]
#### Patricia's note:
# Also known as stroke. Consider add snomed#62914000 - cerebrovascular disease (disorder)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cogan_syndrome_codes = ['405810005',#Cogan’s syndrome
                       ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
ccr_codes = [
  '93761005', #Primary malignant neoplasm of colon (disorder)
  '93984006', #Primary malignant neoplasm of rectum (disorder)
  '408645001', #Adenocarcinoma of large intestine (disorder)
  '254582000'  #Adenocarcinoma of rectum (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
chronic_kidney_disease_codes = [
  '709044004'      # Chronic kidney disease (disorder)
]
#### Patricia's note:
# Chronic kidney disease ("CKD") leads to chronic renal failure (minimal difference between those terms in medicine), see below. If extreme, consider dialysis (snomed#265764009) which includes hemodialysis and peritoneal dialysis). Labs related: BUN and creatinine
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
chronic_kidney_disease_T2D_Hyp_codes = [
  '709044004'      # Chronic kidney disease (disorder)
]
#### Alex's Note:
# This will remove additional SNOMED codes related to T2D and hypertension using the patches_cc_registry. 
# The SNOMED codes below are what will remain after patches removal. Do not edit this cell in any way. 
# Please ask Alex if you have any questions.

# CKD related to T2D
#   '771000119108', #Chronic kidney disease due to type 2 diabetes mellitus (disorder)
#   '157141000119108', #Proteinuria due to type 2 diabetes mellitus (disorder)
#   '90781000119102', #Microalbuminuria due to type 2 diabetes mellitus (disorder)
#   '368201000119100', #Disorder of kidney due to drug induced diabetes mellitus (disorder) 
#   '71441000119104', #Nephrotic syndrome due to type 2 diabetes mellitus (disorder)
#   '792926007', #Armanni-Ebstein kidney due to diabetes mellitus (disorder) 
#   '723074006', #Renal papillary necrosis due to diabetes mellitus (disorder) 
#   '309426007', #Glomerulopathy due to diabetes mellitus (disorder) 
#   '420279001', #Renal disorder due to type 2 diabetes mellitus (disorder)
#   '126551000119103', #Nephropathy due to secondary diabetes mellitus (disorder)

#   CKD related to Hypertension
#   '284961000119106', #Chronic kidney disease due to benign hypertension (disorder)
#   '104931000119100', #Chronic kidney disease due to hypertension (disorder)
#   '117681000119102', #Chronic kidney disease stage 1 due to hypertension (disorder)
#   '129181000119109', #Chronic kidney disease stage 2 due to hypertension (disorder)
#   '129171000119106', #Chronic kidney disease stage 3 due to hypertension (disorder)
#   '129151000119102', #Chronic kidney disease stage 4 due to hypertension (disorder)
#   '129161000119100', #Chronic kidney disease stage 5 due to hypertension (disorder)
#   '111411000119103' #End stage renal disease due to hypertension (disorder)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
chronic_liver_disease_codes = [
  '328383001'     # Chronic liver disease (disorder)
]
# Includes all chronic liver diseases (viral hepatitis, alcohol, intoxication, cirrhosis, etc)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
chronic_lung_disease_codes = [
  '413839001'      # Chronic lung disease (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note:
copd_codes = [
  '13645005', # Chronic obstructive lung disease (disorder)
  '87433001', # Emphysema (disorder)
  '185086009', # Chronic bronchitis
]
# Usually related to smoking. It may present as emphysema (snomed#87433001) or chronic bronchitis (snomed#185086009)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
chronic_renal_failure_codes = [
  '90688005'     # Chronic renal failure syndrome (disorder)
]
#### Patricia's note:
# Please see chronic kidney disease
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
churg_strauss_codes = [
  '82275008'     # Allergic granulomatosis angiits (disorder)
]
# Most often known as Churg-Strauss syndrome
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cholangiocarcinoma_codes = ['312104005', #Cholangiocarcinoma of biliary tract
                           ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cirrhosis_liver_cooccurrent_codes = ['735733008', #Cirrhosis of liver co-occurrent 
                                    ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
cold_agglutinin_disease_codes = ['398937006', #Cold agglutinin disease
                                ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
congestive_heart_failure_codes = [
  '42343007'# Congestive heart failure (disorder
]
#### Patricia's note:
# Also known as heart failure (snomed#84114007, see below) and systolic heart failure (snomed#417996009). Congestive heart failure may lead to acute pulmonary edema (see above)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Patricia's note:
constipation_codes = [
  '14760008'     # Constipation (finding)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
coronary_artery_disease_codes = [
  '53741008',      # Coronary arteriosclerosis (disorder)
  '413844008'      # Chronic myocardial ischemia (disorder)
]
#### Patricia's note:
# It's a type of arteriosclerotic vascular disease (see above), located in the heart arteries called coronary arteries. If severe, leads to myocardial infaction (or heart attack)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
covid_19_codes = [
  '840539006'     # Disease caused by Severe acute respiratory syndrome coronavirus 2 (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note:
covid_outcome = ['674814021000119106', #ards caused by SARS-CoV-2
'882784691000119100', #pneumonia caused by SARS-CoV-2
'189486241000119100', #asymptomatic infection by SARS-CoV-2
'866151004', #lymphopenia caused by SARS-CoV-2
'1240531000000103', #myocarditis caused by SARS-CoV-2
'138389411000119105', #acute bronchitis caused by SARS-CoV-2
'119731000146105', #cardiomyopathy caused by SARS-CoV-2
'1240561000000108', #encephalopathy caused by SARS-CoV-2
'866151004', #lymphocytopenia caused by SARS-CoV-2
'866152006', #thrombocytopenia caused by SARS-CoV-2
'880529761000119102', #lower respiratory infection caused by SARS-CoV-2
'870588003', #sepsis due to disease caused by SARS-CoV-2
'674814021000119106', #ARDS due to SARS-CoV-2
'870591003', #rabdomyolysis caused by SARS-CoV-2
'870589006', #acute kidney injury caused by SARS-CoV-2
'870590002'] #acute respiratory failure caused by SARS-CoV-2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note:
creutzfeldt_disease_codes = [
  '792004'      # Creutzfeldt's disease (disorder)
]
# Rare condition that present as dementia and neurologic deterioration. If it got from cattle, it's known as "mad cow"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Qi's note
#### verifed, merge with Wanessa's autoimmune dictionary
crohns_disease_codes = [
  '34000006',      # Crohn's disease (disorder)
  '410485009',     # Iritis with Crohn's disease (disorder)
]
#### Patricia's note:
# Crohn's disease is a type of inflammatory bowel disease or IBD (snomed#24526004). It's characterized by inflammation of intestine and anus, but it can also affect esophagus, stomach, and duodenum. It may have some extra-intestinal manifestations, such as arthitis. Main features are chronic diarrhea and abdominal pain.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
deep_vein_thrombosis_codes = [
  '128053003'      # Deep venous thrombosis (disorder)
]
#### Patricia's note:
# Clot in profound veins, usually legs. The consequences are pulmonary embolism if the clot migrate to the lungs and chronic venous insufficiency if the clot stays there and jeopardize the venous circulation. Treatment is anticoagulation.
# Venous thrombosis (snomed#111293003) is the parent and includes superficial veins thrombosis
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dermatitis_herpetiformis_codes = ['111196000', #Dermatitis herpetiformis
                                 ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dementia_codes = [
  '52448006'      # Dementia (disorder)
]
#### Patricia's note:
# It's a non-reversible intelligence impairment acquired with aging or genetic condition but not at birth. It can be a manifestation of the following diseases: 'alzheimer','dementia','senile degeneration of brain','huntington','lewy','creutzfeldt','normal pressure hydrocephalus','wernicke-korkakoff'
# Please refer to dementia notebook for more details
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
depression_codes = [
  '35489007'      # Depressive disorder (disorder)
]
#### Patricia's code:
# Depression is very broad and includes postpartum depression, depression caused by amphetamine, depression and schizoprenia, etc
# For depression study, consider using major depression disorder (snomed#370143000). Also, depression may be a presentation of bipolar disorder (snomed#13746004)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
dermatomyositis_codes = [
  '396230008'     # Dermatomyositis (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
diabetes_type_1_codes = [
  '46635009'      # Diabetes mellitus type 1 (disorder)
]

diabetes_type_2_codes = [
  '44054006',      # Diabetes mellitus type 2 (disorder)
  '791000119109', #Angina due to type 2 diabetes mellitus (disorder)
  '421631007', #Gangrene due to type 2 diabetes mellitus (disorder)
  '41911000119107', #Glaucoma due to type 2 diabetes mellitus (disorder)
  '420756003', #Cataract of eye due to diabetes mellitus type 2 (disorder)
  '721284006', #Acidosis due to type 2 diabetes mellitus (disorder)
  '60951000119105', #Blindness due to type 2 diabetes mellitus (disorder)
  '110171000119107', #Ulcer of lower limb due to type 2 diabetes mellitus (disorder)
  '1531000119102', #Dermopathy due to type 2 diabetes mellitus (disorder)
  '15936501000119100', #Inflammatory dermatosis due to type 2 diabetes mellitus (disorder)
  '427027005', #Lumbosacral radiculoplexus neuropathy due to type 2 diabetes mellitus (disorder)
  '102621000119101', #Ulcer of skin due to type 2 diabetes mellitus (disorder)
  '368581000119106', #Neuropathy due to type 2 diabetes mellitus (disorder)
  '1521000119100', #Ulcer of foot due to type 2 diabetes mellitus (disorder)
  '314903002', #Arthropathy due to type 2 diabetes mellitus (disorder)
  '422034002', #Retinopathy due to type 2 diabetes mellitus (disorder)
  '761000119102', #Dyslipidemia due to type 2 diabetes mellitus (disorder)
  '395204000', #Hyperosmolar non-ketotic state due to type 2 diabetes mellitus (disorder)
  '713703005', #Gastroparesis due to type 2 diabetes mellitus (disorder)
  '72061000119104', #Osteomyelitis due to type 2 diabetes mellitus (disorder)
  '713706002', #Polyneuropathy due to type 2 diabetes mellitus (disorder)
  '137931000119102', #Hyperlipidemia due to type 2 diabetes mellitus (disorder)
  '420436000', #Mononeuropathy due to type 2 diabetes mellitus (disorder)
  '82551000119103', #Rubeosis iridis due to type 2 diabetes mellitus (disorder)
  '72051000119101', #Severe malnutrition due to type 2 diabetes mellitus (disorder)
  '1491000119102', #Vitreous hemorrhage due to type 2 diabetes mellitus (disorder)
  '427134009', #Small vessel disease due to type 2 diabetes mellitus (disorder)
  '701000119103', #Mixed hyperlipidemia due to type 2 diabetes mellitus (disorder)
  '428007007', #Erectile dysfunction due to type 2 diabetes mellitus (disorder)
  '16891151000119103', #Coronary artery disease due to type 2 diabetes mellitus (disorder)
  '422166005', #Peripheral circulatory disorder due to type 2 diabetes mellitus (disorder)
  '368101000119109' #Periodontal disease co-occurrent and due to diabetes mellitus type 2 (disorder)
]

diabetes_gestational_codes = [
  '199223000'      # Diabetes mellitus type 2 (disorder)
]

diabetes_type1and2_codes = diabetes_type_1_codes + diabetes_type_2_codes
diabetes_codes = diabetes_type1and2_codes + diabetes_gestational_codes
#### Patricia's note: 
# Diabetes mellitus in general (snomed#73211009) includes gestational diabetes (snomed#199223000), some genetic conditions, and diabetes mellitus due to pancreatic injury.
# Remember that the high blood sugar is diabetes MELLITUS. There is other kind of diabetes, called diabetes INSIPIDUS, which is the lack of a hormone and causes excess of urination, and IS NOT related to blood sugar
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
diarrhea_codes = [
  '267060006'     # Diarrhea symptom (finding)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
diverticulitis_codes = [
  '307496006', # Diverticulitis (disorder)
]
# Inflammation in the setting of diverticulosis (see below)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
diverticulosis_codes = [
  '63532004', # Diverticulosis of intestine (disorder)
]
# Pouchs in the intestines, usually asymptomatic, but it can cause bleeding. If inflammation, please use code above (diverticulitis)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
encephalopathy_codes = [
  '81308009'      # Disorder of brain (disorder)
]
#### Patricia's note:
# Very broad term, it's a neurologic impairment, usually temporary, caused by alcoholism, cirrhosis, renal failure, cerebal edema etc. It can become irreversible
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Patricia's note:
endometriosis_codes = [
  '129103003'     # Endometriosis (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
endometrial_cancer_codes = [
  '93781006',     # Primary malignant neoplasm of endometrium (disorder)
  '447266004',     # Sarcoma of endometrium (disorder)
  '92582009',     # Carcinoma in situ of endometrium (disorder)
  '840516000',     # Complex mixed and stromal malignant neoplasm of endometrium of corpus uteri (disorder)
  '419327006',     # Endometrial intraepithelial neoplasia (disorder)
  '369507007',     # Malignant tumor involving vulva by direct extension from endometrium (disorder)
  '369448007',     # Malignant tumor involving rectum by direct extension from endometrium (disorder)
  '369469009',     # Malignant tumor involving bladder by direct extension from endometrium (disorder)
  '369588000',     # Malignant tumor involving vulva by separate metastasis from endometrium (disorder)
  '369595009',     # Malignant tumor involving an organ by direct extension from endometrium (disorder)
  '369455009',     # Malignant tumor involving rectum by separate metastasis from endometrium (disorder)
  '369582004',     # Malignant tumor involving vagina by separate metastasis from endometrium (disorder)
  '369476004',     # Malignant tumor involving bladder by separate metastasis from endometrium (disorder)
  '369524001',     # Malignant tumor involving left ovary by direct extension from endometrium (disorder)
  '369531002',     # Malignant tumor involving right ovary by direct extension from endometrium (disorder)
  '369603003',     # Malignant tumor involving an organ by separate metastasis from endometrium (disorder)
  '16754641000119104',     #Abnormal uterine bleeding due to primary malignant neoplasm of endometrium (disorder) 
  '369560006',     # Malignant tumor involving left ovary by separate metastasis from endometrium (disorder)
  '369568004',     # Malignant tumor involving right ovary by separate metastasis from endometrium (disorder)
  '369515005',     # Malignant tumor involving left fallopian tube by direct extension from endometrium (disorder)
  '369547000',     # Malignant tumor involving right fallopian tube by direct extension from endometrium (disorder)
  '369542006',     # Malignant tumor involving left fallopian tube by separate metastasis from endometrium (disorder)
  '369553000'     # Malignant tumor involving right fallopian tube by separate metastasis from endometrium (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
evans_syndrome_codes = ['75331009', #Evans syndrome
                       ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
gerd_codes = [
  '235595009'     # Gastroesophageal reflux disease (disorder)
]
#### Patricia's note:
# GERD = gastroesophageal reflux disorder
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
gtd_codes = [
  '416402001'     # Gestational trophoblastic disease (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
gi_bleed_codes = [
   '37372002', # upper gastrointestinal hemorrhage
   '87763006'  # lower gastrointestinal hemorrhage
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
graft_disease_codes = [
  '234646005'     # Graft-versus-host disease (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note:
gb_codes = [
  '40956001'     # Guillain-Barre syndrome (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
heart_failure_codes = [
  '84114007'      # Heart failure (disorder)
]
#### Patricia's note:
# See above congestive cardiac failure
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
hpylori_codes = [
  '721730009', # Helicobacter pylori gastrointestinal infection (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
hemato_neoplasm_codes = [
  '414825006' #Neoplasm of hematopoietic cell type (disorder)
]
# Includes all benign, pre-malignant, and malignant neoplasm of hematopoietic system (lymph nodes and bone marrow)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
HBV_codes = [
  '66071002', #Hepatitis type B virus (HBV) (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
HCV_codes = [
  '50711007' #Hepatitis C virus (HCV) (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
HDV_codes = [
  '707341005' #Hepatitis type D virus (HDV) (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
HEV_codes = [
  '7111000119109' #Hepatitis type E virus (HEV) (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
hidradenitis_codes = [
  '59393003'     # Hidradenitis suppurativa (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
bariatric_codes = [
  '608848006'     # History of bariatric surgery (situation)
]
# History of bariatric surgery (surgery to treat obesity), it does not include endoscopi procedures
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
tx_codes = [
  '737300001', #bone marrow transplant (finding)
  '739024006', #heart transplant
  '737295003', #kidney transplant
  '737297006', #liver transplant
  '737296002' #lung transplant
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's codes
hiv_codes = [
  '86406008'      # HIV (disorder)
]
#### Patricia's note:
# Status of having HIV, it may be asymptomatic or present AIDS symptoms
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note:
huntington_codes = [
  '58756001'     # Huntington's chorea (disorder)
]
# Huntingon's disease is a genetic disease that manifests with dementia (see above) and neurologic symptoms
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note:
hypercoagulability_codes = [
  '76612001'     # Hypercoagulability state (finding)
]
# It's preferred to use labs (PT, APTT, platelets, fibrinogen, d-dimer, and others)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note:
hld_codes = [
  '55822004'     # Hyperlipidemia (disorder)
]
# Hyperlipidemia is the increase of fat (cholesterol) in blood, very generic term but often used
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Non-pregnancy-related hypertension SNOMED codes
hypertension_codes = [
  #   '10725009',         # Benign hypertension
#   '720568003',        # Brachydactyly and arterial hypertension syndrome
#   '48146000',         # Diastolic hypertension
  '59621000',         # Essential hypertension
#   '429198000',        # Exertional hypertension
#   '71701000119105',   # Hypertension in chronic kidney disease due to type 1 diabetes mellitus
#   '71421000119105',   # Hypertension in chronic kidney disease due to type 2 diabetes mellitus
#   '397748008',        # Hypertension with albuminuria
#   '706882009',        # Hypertensive crisis
#   '697929007',        # Intermittent hypertension
#   '70272006'          # Malignant hypertension
#   '1078301000112109', # Multiple drug intolerant hypertension
#   '206596003',        # Neonatal hypertension
#   '23130000',         # Paroxysmal hypertension
#   '5501000119106',    # Postoperative hypertension
#   '118781000119108',  # Pre-existing hypertensive chronic kidney disease in mother complicating pregnancy
#   '84094009',         # Rebound hypertension
  '31992008'          # Secondary hypertension
]

# Pregnancy-related hypertension SNOMED codes
hypertension_pregnancy_related_codes = [
  '69909000',        # Eclampsia added to pre-existing hypertension
  '198941007',       # Hypertension complicating pregnancy, childbirth and the puerperium
  '367390009',       # Hypertension in the obstetric context
  '48194001'         # Pregnancy-induced hypertension
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Patricia's note:
hypothyroidism_codes = [
  '59282003'     # Hypothyroidism (disorder)
]
## Labs: TSH, T4 (free), T3
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ipf_codes =  [
'700250006',  #Idiopathic pulmonary fibrosis (disorder)
'70024900' ,  #Idiopathic interstitial pneumonia (disorder)
'708031000' , #Idiopathic eosinophilic pneumonia (disorder)
'1172606002', #Idiopathic pleuroparenchymal fibroelastosis (disorder)
'236302005' , #Acute interstitial pneumonia (disorder)
'789574002' , #Acute exacerbation of idiopathic pulmonary fibrosis (disorder)
'719218000' , #Cryptogenic organizing pneumonia (disorder)
'8549006'  ,  #Desquamative interstitial pneumonia (disorder)
'426437004',  #Familial idiopathic pulmonary fibrosis (disorder)
'44274007' ,  #Lymphocytic interstitial pneumonia (disorder)
'129452008'  #Nonspecific interstitial pneumonia (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
immune_codes = [
  '234532001'     # Immunodeficiency (disorder)
]
# Very broad, please refer to the immunocompromised notebook for the complete code
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
ulcerative_colitis_codes = [
  '64766004',     # Ulcerative colitis disease (disorder)
  '201807008',    # Juvenile arthritis in ulcerative colitis (disorder)
  '201727001',    # Arthropathy in ulcerative colitis (disorder)
  '732966008',    # Secondary autoimmune hemolytic anemia co-occurrent and due to ulcerative colitis (disorder)
]
# It's a type of inflammatory bowel disease (IBD, see above) and caused inflammation of large intestine (colon).
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Qi's note
#### verified
other_ibd_codes = [
  '24526004',     # IBD (disorder)
  ## New added based on Wanessa's autoimmune dictionary
  '239814006',     # Seronegative arthritis secondary to inflammatory bowel disease (disorder)
  '239809007',     # Juvenile arthritis of inflammatory bowel disease (disorder)
  '1144956000',    # Vasculitis due to inflammatory bowel disease (disorder)
  '1186652002',    # Inflammatory bowel disease, recurrent sinopulmonary infection syndrome (disorder)
  '1186721005',    # Infantile inflammatory bowel disease with neurological involvement (disorder)
]

ibd_codes = other_ibd_codes + ulcerative_colitis_codes + crohns_disease_codes
# Inflammation of intestines. It can be Crohn's disease or ulcerative colitis.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
inf_arth_codes = [
  '26071001'     # IBD (disorder)
]
# Inflammation of intestines. It can be Crohn's disease or ulcerative colitis.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
influenza_codes = [
  '6142004'     # Influenza (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Patricia's note:
insomnia_codes = [
  '193462001'     # Insomnia (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
ibs_codes = [
  '10743008'     # IBS (disorder)
]
# When patient feels abdominal pain, diarrhea and/or constipation but all testing are normal. Several theories to explain.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
kidney_cancer_codes = [
  '363518003'     # Malignant tumor of kidney (disorder)
]
#Alex's note: Excludes 94360002 |Secondary malignant neoplasm of kidney (disorder) in patches_cc_registry per Andria's reccomendation
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
dialysis_codes = [
  '265764009'     # Kidney dialysis (procedure)
]
# Includes all types of dialysis
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
leukemia_codes = [
  '93143009'   # Leukemia, disease (disorder)
]

chronic_lymphoid_leukemia_codes = [
  '92814006'   # Chronic lymphoid leukemia, disease (disorder)
]

chronic_myeloid_leukemia_codes = [
  '92818009'   # Chronic myeloid leukemia, disease (disorder)
]

acute_lymphoid_leukemia_codes = [
  '91857003'   # Acute lymphoid leukemia, disease (disorder)
]

acute_myeloid_leukemia_codes = [
  '91861009'   # Acute myeloid leukemia, disease (disorder)
]
#Patricia's note:
acute_lymphoblastic_codes = [
  '128822004' #Acute lymphoblastic leukemia (disorder)
]

acute_promyelocytic_codes = [
  '28950004' #Acute promyelocytic leukemia (disorder)
]

#### Patricia's note:
# Please refer to immunocompromised notebook for more details
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note:
lewy_disease_codes = [
  '80098002'      # Lewy body disease (disorder)
]
# It's a neurologic disease that manifest as dementia (see above) and Parkinson-like features
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
limited_sclerosis_codes = ['299276009',#Limited sclerosis 
                          ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
hepatocellular_carcinoma_codes = ['109841003', # hepatocellular carcinoma
                                 ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
transplantation_liver_codes = ['18027006', #Transplantation of liver
                              ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
liver_cancer_codes = ['93870000' #Malignant neoplasm of liver (disorder)
                              ]
#Alex's Note: Excludes 94381002 |Secondary malignant neoplasm of liver (disorder) in patches_cc_registry per Andria's reccomendation
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
lymphoma_hodgkin_codes = [
  '118599009'     # Hodgkin's disease (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
lymphoma_nonhodgkin_codes = [
  '118601006'     # Non-Hodgkin lymphoma
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lung_cancer_codes = [
  '93880001',      # Primary malignant neoplasm of lung (disorder)
  '363358000',     # Malignant tumor of lung (disorder)
  '92649001',     # Carcinoma in situ of lung (disorder)
  '457721000124104'     # Metastatic non-small cell lung cancer (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
major_depression_codes = [
  '370143000'     # Major depression disorder (disorder)
]
# For depression studies, it's recommended to use this code
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Patricia's note:
malabsorption_codes = [
  '32230006'     # Malabsorption syndrome (disorder)
]
# Very broad, includes celiac disease, infectious, lactose intorance, auto-immune enteropathy
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
malignant_neoplastic_disease_codes = [
  '363346000',      # Malignant neoplastic disease (disorder)
  '367651003'       # Malignant neoplasm of primary, secondary, or uncertain origin (morphologic abnormality)
]
#### Patricia's note:
# This code includes all type of cancer in any stage
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
malignant_neoplastic_disease_noBSC_noSCC_codes = [
  '363346000',      # Malignant neoplastic disease (disorder)
  '367651003'       # Malignant neoplasm of primary, secondary, or uncertain origin (morphologic abnormality)
]

#Alex's Note:
#Excludes following conditionsd in patches_cc_registry:
#'429114002', # Malignant basal cell neoplasm of skin (disorder)
#'254651007' #Squamous cell carcinoma of skin (disorder)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
gastric_cancer_codes = ['363349007', #gastric cancer
                       ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
gallbladder_cancer_codes = ['363353009', #gallbladder cancer
                           ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pancreatic_cancer_codes = ['363418001', #pancreatic cancer
                          ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
marijuana_codes = [
  '733460004'     # Marijuana user (finding)
]
# Recreational marijuana user
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
melanoma_codes = ['93655004' # |Malignant melanoma of skin (disorder)
                                       ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mar_codes = ['312941005', #Melanoma-associated retinopathy
                                       ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
multicentric_reticulohistiocytosis_codes = ['84241008', #Multicentric reticulohistiocytosis
                                           ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Qi's note
#### verified, with Wanessa's autoimmune dictionary
multiple_sclerosis_codes = [
  '24700007',      # Multiple sclerosis (disorder)
  '1186728004',    # Pediatric multiple sclerosis (disorder)
  '445967004',     # Clinically isolated syndrome (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
myastenia_codes = [
  '91637004'     # Myastenia gravis (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mycosis_codes = [
  '3218000'      # Mycosis (disorder)
]
### Patricia's note:
# Mycosis is very broad and it can includes toe nail mycosis and severe systemic mycosis. It's recommended specify what microrganism is causing the condition instead of only 'mycosis'
# In addition, MYCOSIS FUNGOIDES is a type of T-cell lymphoma and not an infectious disease (see below)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
mycosis_fungoides_codes = [
  '118618005'     # Mycosis fungoides (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
mds_codes = [
  '109995007' # Myelodysplastic syndrome (disorder)
]
# "Pre-leukemia" disorder
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
myocardial_infarction_codes = [
  '22298006'      # Myocardial infarction (disorder)
]
#### Patricia's note:
# Also known as heart attack. Usually is consequence of coronary artery disease (see above), but it may be result of cocaine, particularly in young patients. Consider adding social history in these cases.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
NAFLD_codes = [
  '197315008'     # Non-alcoholic fatty liver disease (NAFLD)(disorder)
]
####Wanessa's note: group of liver disease that affects who drinks a little to no alcohol
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
nv_codes = [
  '608848006'     # Nausea and vomiting (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# do not use - use lab count instead of diagnoses
neutropenia_codes = [
  '165517008'      # Neutropenia (finding)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
NASH_codes = [
  '442685003'      # Non-alcoholic steatohepatitis (NASH)
]
####Wanessa's note: aggressive type of fatty liver disease with inflammation of the liver. It can progress to cirrhosis and liver failure
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
nph_codes = [
  '30753002'      # Normal pressure hydrocephalus (disorder)
]
# Neurologic condition characterized by dementia, urinary incontinency, and difficulty to walk. Usually affects elderly
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
obesity_codes = [
  '414916001'      # Obesity (disorder)
]
#### Patricia's note:
# It's better to use BMI, to be more precise. BMI >= 30 is obesity
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
osa_codes = [
  '78275009'     # Obstructive sleep apnea (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
opioid_codes = [
  '75544000'     # Opioid dependence (disorder)
]
# Consider adding social history and medication
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
osteoarthritis_codes = [
  '396275006'      # Osteoarthritis (disorder)
]

# Here a;dskfjas;ldkfj ds;lkj
# alkd;sjfakljdf ;akjdsf
#; la;kjdsfl;kajdsf;lk

# ;alkjdsf;ljasd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
osteoporosis_codes = [
  '64859006'      # Osteoporosis (disorder)
]
#### Patricia's note
# Bones become fragile and under risk of fracture. Usually elderly are more affected
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
osteosarcoma_codes = [
  '307576001'     # Osteosarcoma disorder (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
pancreatitis_codes = [
  '75694006', # Pancreatitis (disorder)
]
# Inflammation of pancreas. Most common causes are gallbladder stones and alcohol abuse. Labs: amylase and lipase
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Patricia's note:
pt_immuno_codes = [
  '370388006', # Patient immunocompromised (finding)
]
## Please refer to immunocompromised notebook for the complete immunocompromised status
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
pv_codes = [
  '49420001'     # Pemphigus vulgaris (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
pud_codes = [
  '13200003'     #Peptic ulcer disease or PUD (disorder)
]
# Gastric or duodenal ulcer
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
peripheral_arterial_disease_codes = [
  '840580004'      # Peripheral arterial disease (disorder)
]
#### Patricia's note:
# It's result of arteriovascular disorder (see above), and affects limbs arteries. It can cause poor circulation, and in extreme cases, the limb "dies", which required amputation
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
peripheral_vascular_disease_codes = [
  '400047006', #Peripheral vascular disease
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pneumonia_codes = [
  '233604007'      # Pneumonia (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
polymyositis_codes = [
  '31384009'     # Polymyositis (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Patricia's note:
polyp_codes = [
  '399432003'     # Adenoma of large intestine (disorder)
]
# Polyps and other pre-neoplastic (colorectal) lesions were included
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note:
post_anoxic_codes = [
  '230797001'     # Post-anoxic coma (disorder)
]
# Long-term coma/ sequelae after lack of oxygen or blood supply to the brain
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note:
post_crf_coma_codes = [
  '275470000'     # Post cardiorespiratory arrest coma (disorder)
]
# When a person survives after resuscitation manouver but she/he is in coma
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
pregnancy_tubal_codes = [
  '79586000'     # Tubal pregnancy (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
preeclampsia_codes = [
  '398254007'     # Pre-eclampsia (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
protein_calorie_malnutrition_codes = [
  '238107002'     # Deficiency of macronutrients (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
primary_sclerosing_cholangitis_codes = [
  '197441003',  # Primary sclerosing cholangitis (disorder)
  '735733008',  # Cirrhosis of liver co-occurrent and due to primary sclerosing cholangitis
]
####Wanessa's note: It can be associated to inflammatory bowel disease (IBD)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
secondary_sclerosing_cholangitis_codes = ['197442005', #Secondary sclerosing cholangitis 
                                         ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
primary_biliary_cholangitis_codes = [
  '31712002'     # Primary biliary cholangitis (disorder)
]
####Wanessa's note: caused by chronic inflammation in the liver
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
HIV_related_sclerosing_cholangitis_codes = ['281388009', # HIV-related sclerosing cholangitis
                                         ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
neonatal_sclerosing_cholangitis_codes = ['724278007', #neonatal sclerosing cholangitis
                                 ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
perivenous_encephalomyelitis_codes = ['83942000', # Perivenous encephalomyelitis
                                     ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
prostate_cancer_codes = ['93974005', # Primary malignant neoplasm of prostate (disorder)
                         '715412008', # Familial malignant neoplasm of prostate (disorder)
                         '92691004', # Carcinoma in situ of prostate (disorder)
                         '314994000', # Metastasis from malignant tumor of prostate (disorder)
                         '461511000124101', # Biochemically recurrent prostate cancer (disorder)
                         '722103009', # Hormone sensitive prostate cancer (disorder)
                         '96901000119105', # Prostate cancer metastatic to eye (disorder)
                         '427492003', # Hormone refractory prostate cancer (disorder)
                         '1098981000119101', # Recurrent malignant neoplasm of prostate (disorder)
                         '399590005' # Squamous cell carcinoma of prostate (disorder)
                                     ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
psoriatic_arthritis_codes = [
  ## Old version of PSA codes that have overlapping
#   '156370009',    # Psoriatic arthritis (disorder)
#   '239802003',    # Juvenile psoriatic arthritis (disorder)
#   '239803008',    # Juvenile psoriatic arthritis with psoriasis (disorder)
#   '10629311000119107', # Psoriatic arthritis mutilans (disorder)
#   '1162295001', # Psoriatic arthritis of multiple joints (disorder)
#   '1162306005', # Oligoarticular psoriatic arthritis (disorder)
#   '410482007',  # Iritis with psoriatic arthritis (disorder)
  
  ## New codes based on Wanessa's work here: https://docs.google.com/spreadsheets/d/1ZguapkDsJTRbP9xZSiWc4OK3T33sUCCCkMfUg20Wgj0/edit#gid=1077580739
  '156370009',    # Psoriatic arthritis (disorder)
  '410482007',    # Iritis with psoriatic arthritis 
  '239802003',    # Juvenile psoriatic arthritis (disorder)
  '239803008',    # Juvenile psoriatic arthritis with psoriasis (disorder)
  '1162306005',   # Oligoarticular psoriatic arthritis
  '10629311000119107', # Psoriatic arthritis mutilans (disorder)
  '1162295001', # Psoriatic arthritis of multiple joints (disorder)
  '239812005',  # Psoriatic arthritis with distal interphalangeal joint involvement
  '200956002',  # Psoriatic arthritis with spine involvement
  '239813000',  # Psoriatic dactylitis
]
#### Qi's note
#### verfied, with Wanessa's autoimmune dictionary
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Qi's note:
#### Verified, merged with Wanessa's autoimmune dictionary
#### '239803008',    # Juvenile psoriatic arthritis with psoriasis (disorder) is a child node of the PsA parent code
psoriasis_codes = [
  '9014002',     # Psoriasis (disorder)
  '400069004', # Nevoid psoriasis (disorder)
  '111188005', # Psoriasiform napkin eruption (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Patricia's note:
pe_codes = [
  '59282003'     # Pulmonary embolism (disorder)
]
## Warning: usually we want to study pulmonary embolism that is result of deep thrombosis venous (see above). But pulmonary embolism can also includes fat pulmonary embolism (when the fat inside the bones dislodges to the lungs after a fracture), air pulmonary embolism (usually caused by procedures), and obstetric pulmonary embolism (caused by amniotic liquid that disloges to the lungs during delivery)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
renal_impairment_codes = [
  '236423003'     # Renal impairment (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
renal_insufficiency_codes = [
  '723188008'     # Renal insufficiency (disorder)
]
#### Patricia's notes:
# Please see acute and chronic renal (or kidney) disease above
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
respiratory_distress_codes = [
  '271825005'     # Respiratory distress (finding)
]
#### Patricia's note
# In respiratory distress, oxygen saturation and respiratory rate are very important
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rheumatoid_arthritis_codes = [
  '69896004',      # Rheumatoid arthritis (disorder)
  '410502007', # Juvenile rheumatoid arthritis or Juvenile idiopathic arthritis (disorder)
  '201796004', # Systemic onset juvenile rheumatoid arthritis or Systemic onset juvenile chronic arthritis (disorder)
  '1162303002', # Seronegative rheumatoid arthritis with erosion of joint (disorder)
  '129563009', # Rheumatoid arthritis with osteoperiostitis (disorder)
  '193180002', # Polyneuropathy in rheumatoid arthritis (disorder)
  '193250002', # Myopathy due to rheumatoid arthritis (disorder)
  '38877003', # Rheumatoid arthritis with aortitis (disorder)
  '400054000', # Rheumatoid arthritis with vasculitis (disorder)
  '1149219001', # Rheumatoid arthritis with systemic vasculitis (disorder)
  '59165007', # Rheumatoid arthritis with scleritis (disorder)
  '77522006', # Rheumatoid arthritis with episcleritis (disorder)
  
]
#### Qi's note
#### verified, merge with Wanessa's autoimmune dictionary
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Qi's note
#### Verified
sarcoidosis_codes = [
  '31541009',     # Sarcoidosis (disorder)
  ## Added by Qi using the list
  '75403004',     #Cardiac sarcoidosis (disorder)
  '55941000',      #Cutaneous sarcoidosis (disorder)
  '232458003',     #Laryngeal sarcoidosis (disorder)
  '64757003',    #Lymph node sarcoidosis (disorder)
  '232368009',   #Nasal sarcoidosis (disorder)
  '234528007',  #Nasopharyngeal sarcoidosis (disorder)
  '230193008',   #Neurosarcoidosis (disorder)
  '234526006',  #Ocular sarcoidosis (disorder)
  '24369008',     #Pulmonary sarcoidosis (disorder)
  '735433009',      #Sarcoidosis of digestive system (disorder)
  '707238003',    #Sarcoidosis of oral cavity (disorder)
  '425384007',   #Sarcoidosis with glomerulonephritis (disorder)
  '21787007',   #Sarcoidosis, Darier-Roussy type (disorder)
  '17363001',    #Splenic sarcoidosis (disorder)
  '80941006',   #Subcutaneous sarcoidosis (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
schizophrenia_codes = [
  '58214004'     # Schizophrenia (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
seizure_codes = [
  '91175000'     # Seizure (finding)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
senile_codes = [
  '45864009'     # Senile degeneration of brain (disorder)
]
# It's a kind of dementia (see above) related to aging
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sepsis_codes = [
  '91302008'     # Sepsis (disorder)
]
#### Patricia's note:
# Very broad, it's generalized infection
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note:
shock_codes = [
  '27942005'     # Shock (disorder)
]
# Includes all types of shock: burn, sepsis, cardiogenic, traumatic, hypovolemic etc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Qi's note
#### list of snomed codes provided by Dr.Mease etc.

enthesitis_codes = [
  '359643005' #Enthesitis (disorder)
]
dactylitis_codes = [
  '264516005' #Dactylitis (disorder) 
]
inflammation_of_sacroiliac_joint_codes = [
  '55146009' #Inflammation of sacroiliac joint (disorder) 
]
spinal_enthesopathy_codes =[
  '10317009' #Spinal enthesopathy (disorder)
]
axial_spondyloarthritis_codes =[
  '723116002' #Axial spondyloarthritis (disorder)
]
peripheral_spondyloarthritis_codes =[
  '724606001' #Peripheral spondyloarthritis (disorder)
]

#enthesitis_codes +
spondyloarthritis_codes =  dactylitis_codes + inflammation_of_sacroiliac_joint_codes + spinal_enthesopathy_codes + axial_spondyloarthritis_codes + peripheral_spondyloarthritis_codes

##### note:
#high_risk = axial_spondyloarthritis_codes +
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
stroke_codes = [
  '230690007'      # Cerebrovascular accident (disorder)
]
#### Patricia's note
# See cerebovascular disease above
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sirs_codes = [
  '238149007'     # Systemic inflammatory response syndrome (disorder)
]
#### Patricia's note:
# It's when the body tried to defends itself releasing substances to kill bugs, but not always triggers by infection. Usually severe and required intensive care
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Qi's note
#### verified
sle_codes = [
  '55464009', # Systemic lupus erythematosus (disorder)
  '68815009',     # Lupus nephritis (disorder)
  #####
  '200936003', # Lupus erythematosus (disorder)
  '200940007', # Lupus erythematosus nodularis (disorder)
  '402711009', # Lupus erythematosus overlap syndrome (disorder)
  '397856003', # Systemic lupus erythematosus-related syndrome (disorder)
  '95609003', # Neonatal lupus erythematosus (disorder)
]
# Auto-immune disorder
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
sympathetic_ophthalmia_codes = ['75315001', #Sympathetic ophthalmia (SO)
                               ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Qi's note
#### verified
scleroderma_codes = [
  '89155008',     # Systemic sclerosis (disorder)
  '22784002', # Linear scleroderma (disorder)
  '322461000119108', # Polyneuropathy due to systemic sclerosis (disorder)
  '193252005', # Myopathy due to scleroderma (disorder)
  '402713007', # Cutaneous complication of systemic sclerosis (disorder)
  '35719004', # Dilated cardiomyopathy due to systemic sclerosis (disorder)
  '403518009', # Scleroderma-associated necrotizing vasculitis (disorder)
  '1144925008', # Diffuse systemic sclerosis of childhood (disorder)
  
]
# Also known as 'scleroderma'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Qi's note
#### verified
sjogren_syndrome_codes = [
  '83901003', #Sjögren's syndrome (disorder)
  '239912009', #Primary Sjögren's syndrome (disorder)
  '239915006', #Secondary Sjögren's syndrome
  '762303003', #Pediatric onset Sjögren syndrome (disorder)
  '196137000', #Lung disease with Sjögren's disease (disorder)
  '724782005', #Demyelination of central nervous system co-occurrent and due to Sjogren disease (disorder)
  
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
tachycardia_codes = [
  '3424008'     # Tachycardia (finding)
]
#### Patricia' note:
# It's a type of arrhythmia, when the heart rate is above 100 (see above)). The opposite is bradicardia (too slow)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
thyroid_cancer_codes = [
  '92767001',     # Carcinoma in situ of thyroid gland (disorder)
  '94098005',     # Primary malignant neoplasm of thyroid gland (disorder)
  '314953008',     # Local recurrence of malignant tumor of thyroid gland (disorder)
  '448216007',     # Malignant epithelial neoplasm of thyroid (disorder)
  '255032005'     # Medullary thyroid carcinoma (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
turner_syndrome_codes = [
  '38804009' # Turner syndrome (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia' note:
tobacco_codes = [
  '89765005',     # Tobacco dependence (disorder)
  '77176002',     # Current smoker (finding)
]
# Recommended to use with social history. This snomed codes included chew tobacco
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
transverse_myelitis_codes = ['16631009', #Transverse myelitis
                            ]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
traumatic_brain_injury_codes = [
  '127295002'      # Traumatic brain injury (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia's note
triple_codes = [
  '706970001'     # Triple negative malignant neoplasm of breast (disorder)
]
# Breast cancer with some molecular characteristics, usually poor prognosis
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
urinary_tract_infection_codes = [
  '68566005'     # Urinary tract infectious disease (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
## Qi has verified to be the same as this doc: https://docs.google.com/spreadsheets/d/1ZguapkDsJTRbP9xZSiWc4OK3T33sUCCCkMfUg20Wgj0/edit#gid=1135479034
uveitis_codes = [
# '128473001'] #Uveitis (disorder)
# '75614007']   #Panuveitis or Diffuse uveitis(disorder)
# '444248002'] #Chronic inflammation of uveal tract (disorder)
# '410501000']  #Drug-induced uveitis (disorder)
# '4927003']  #Acute anterior uveitis (disorder)
# '64015001']  #Subacute anterior uveitis (disorder)
# '43363007']  #Posterior uveitis (disorder)
  #Wanessa's notes: these are the general codes for uveitis above, but they are for any inflammation of the uvea, not specifically for IMIDs
  #UVEITIS (IMIDs)
  '415359008',   # Sarcoid uveitis (disorder)
  '1144978007', # Anterior uveitis due to sarcoidosis (disorder)
  '86219005',        # Uveitis-rheumatoid arthritis syndrome (disorder)
  '416666007',   # Anterior uveitis due to juvenile idiopathic arthritis (disorder)
  '418839003',      # Tubulointerstitial nephritis with uveitis syndrome (disorder)
  '786077003',  # Ankylosing spondylitis co-occurrent with anterior uveitis (disorder)
  '1156845007',   # Uveitis due to extended onset antinuclear antibody negative juvenile idiopathic oligoarthritis (disorder)
  '1156846008',   # Uveitis due to extended onset antinuclear antibody positive juvenile idiopathic oligoarthritis (disorder)
  '726078000',    # Sporadic Blau syndrome (disorder)
  '818950005',     # Blau syndrome (disorder)
  '410481000',    # Panuveitis in Behcet's syndrome (disorder)
  '1144919009',    # Behcet disease of eye (disorder)
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
autoimmune_vasculitis = [
  '427213005' # general code for vasculitis
]
#Wanessa's note: this is the general code for vasculitis on above
#Jenn's note: do not use this general code for rheumatologic vasculatitis. Instead, combine  small, medium and large vessel definitions below. Question for Dr. Mease - should we use the term "rheumatologic vasculatitis", or "autoimmune vasculitis", or some other classification?

small_vessel_vasculitis_codes = [
  '724599009', # Small vessel vasculitis (disorder),
  '82275008',  # Allergic granulomatosis angiitis (disorder)or eosinophilic granulomatosis with polyangiitis or Churg-Strauss’ syndrome
  '310701003',    # Behcet syndrome (disorder)
  '30911005', # Cryoglobulinemia (disorder)
  '718217000',      # Cutaneous leukocytoclastic angiitis (disorder)
  '195353004',   # Granulomatosis with polyangiitis (disorder) or Wegner’s syndrome
  '191306005', # Immunoglobulin A vasculitis (disorder) or Henoch-Schonlein purpura
  '1144805008' # Microscopic polyangiitis (disorder)
]

medium_vessel_vasculitis_codes = [
  '155441006', # Polyarteritis nodosa (disorder)
  '75053002', # Acute febrile mucocutaneous lymph node syndrome (disorder) or Kawasaki disease
  '2403007'     # Thromboangiitis obliterans (disorder)= Buerger’s disease
]

large_vessel_vasculitis_codes = [
  '230732009',     # Cerebral arteritis in giant cell arteritis (disorder)
  '239938009', # Giant cell arteritis with polymyalgia rheumatica (disorder)
  '239939001', # Giant cell arteritis without polymyalgia rheumatica (disorder)
  '722020006',    # Juvenile temporal arteritis (disorder)
  '359789008',  # Takayasu's disease (disorder) or young female arteritis
]

vasculitis_codes = small_vessel_vasculitis_codes + medium_vessel_vasculitis_codes + large_vessel_vasculitis_codes

## Other codes and types of autoimmune vasculitis
other_codes_and_types_of_autoimmune_vasculitis_codes = [
  '50581000', #Anti-GBM disease or Goodpasture
  '722191003', # Antineutrophil cytoplasmic antibody positive vasculitis
  '405810005', # Cogan's syndrome
  '403616000', # Drug-induced lymphocytic vasculitis
  '402659000', # Drug-induced necrotizing vasculitis
  '23878600', # Gougerot-Ruiter purpura
  '239945009', # Hypocomplementemic urticarial vasculitis
#   '239944008', # Lupus vasculitis, move to lupus?
  '699814001', # Primary angiitis of central nervous system
  '402416000', # Urticarial vasculitis with monoclonal immunoglobulin M component, Schnitzler
  '770687001' # Vasculitis due to adenosine deaminase 2 deficiency
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#### Patricia-s note:
wk_infection_codes = [
  '69482004'     # Wernicke-Korsakoff disease (disorder)
]
# Neurologic condition characterized by irreversible memory impairment usually caused by alcoholism and tiamin deficiency. Also known as 'psychosis' because patient doesn't rememeber things and makes up stories
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
conditions_cc_registry = {
  'abdominal_pain' : abd_codes,
  'acute_lymphoid_leukemia': acute_lymphoid_leukemia_codes,
  'acute_myeloid_leukemia': acute_myeloid_leukemia_codes,
  'acute_pulmonary_edema': acute_pulmonary_edema_codes,
  'acute_renal_failure': acute_renal_failure_codes,
  'adrenal_insufficiency': adrenal_insufficiency_codes,
  'aids' : aids_codes,
  'alcoholism' : alcoholism_codes,
  'alzheimer': alzheimer_failure_codes,
  'anemia' : anemia_codes,
  'ankylosing_spondylitis': ankylosing_codes,
  'APS': antiphospholipid_syndrome_codes,
  'appendectomy' : appendectomy_codes,
  'appendicitis' : appendicitis_codes,
  'ards': ards_codes,
  'acute_respiratory_failure': acute_respiratory_failure_codes,
  'arthritis': arthritis_codes,
  'arteriosclerotic_vascular_disease': arteriosclerotic_vascular_disease_codes,
  'asplenia' : asplenia_codes,
  'asthma': asthma_codes,
  'atrial_fibrillation': atrial_fibrillation_codes,
  'autoimmune_disease_noSjorgren': autoimmune_disease_noSjorgren_codes,
  'auto_immune_hepatitis' : auto_hepatitis_codes,
  'auto_enteropathy': auto_enteropathy_codes,
  'auto_pap': auto_pap_codes, 
  'axial_spondyloarthritis' : axial_spondyloarthritis_codes,
  'benign_prostatic_hyperplasia' : bph_codes,
  'bipolar' : bipolar_codes,
  'bladder_cancer': bladder_cancer_codes,
  'breast_cancer' : breast_codes,
  'blood_loss': blood_loss_codes,
  'cardiac_arrhythmia': cardiac_arrhythmia_codes,
  'cardiorespiratory_failure' : crf_codes,
  'cbd_use' : cbd_codes,
  'cdifficile_infection' : cdfficile_codes,
  'cerebrovascular_accident': cerebrovascular_accident_codes,
  'cholangiocarcinoma': cholangiocarcinoma_codes,
  'chronic_kidney_disease': chronic_kidney_disease_codes,
  'chronic_kidney_disease_T2D_Hyp': chronic_kidney_disease_T2D_Hyp_codes,
  'chronic_liver_disease' : chronic_liver_disease_codes,
  'chronic_lung_disease': chronic_lung_disease_codes,
  'chronic_lymphoid_leukemia': chronic_lymphoid_leukemia_codes,
  'chronic_myeloid_leukemia': chronic_myeloid_leukemia_codes,
  'chronic_renal_failure': chronic_renal_failure_codes,
  'churg_strauss': churg_strauss_codes,
  'cirrhosis_liver_cooccurrent': cirrhosis_liver_cooccurrent_codes,
  'cogan_syndrome': cogan_syndrome_codes,
  'cold_agglutinin_disease': cold_agglutinin_disease_codes,
  'colorectal_cancer' : ccr_codes,
  'congestive_heart_failure': congestive_heart_failure_codes,
  'constipation' : constipation_codes,
  'copd': copd_codes,
  'coronary_artery_disease': coronary_artery_disease_codes,
  'covid_19': covid_19_codes,
  'covid_outcomes' : covid_outcome,
  'creutzfeldt': creutzfeldt_disease_codes,
  'crohns_disease': crohns_disease_codes,
  'dactylitis' : dactylitis_codes,
  'deep_vein_thrombosis': deep_vein_thrombosis_codes,
  'dementia': dementia_codes,
  'depression': depression_codes,
  'dermatomyositis': dermatomyositis_codes,
  'dermatitis_herpetiformis': dermatitis_herpetiformis_codes,
  'diabetes': diabetes_codes,
  'diabetes_type_1': diabetes_type_1_codes,
  'diabetes_type_2': diabetes_type_2_codes,
  'diabetes_type1and2': diabetes_type1and2_codes,
  'diabetes_gestational': diabetes_gestational_codes,
  'diarrhea' : diarrhea_codes,
  'diverticulitis' : diverticulitis_codes,
  'diverticulosis' :diverticulosis_codes,
  'encephalopathy': encephalopathy_codes,
  'endometriosis': endometriosis_codes,
  'endometrial_cancer': endometrial_cancer_codes,
  'enthesitis' : enthesitis_codes,
  'evans_syndrome': evans_syndrome_codes,
  'gastric_cancer':gastric_cancer_codes,
  'gallbladder_cancer':gallbladder_cancer_codes,
  'gerd': gerd_codes,
  'gi_bleeding' : gi_bleed_codes,
  'gestational_trophoblastic_disease': gtd_codes,
  'graft_versus_host_disease': graft_disease_codes,
  'guillain_barre': gb_codes,
  'heart_failure': heart_failure_codes,
  'hematopoietic_neoplasm' : hemato_neoplasm_codes,
  'hepatocellular_carcinoma': hepatocellular_carcinoma_codes,
  'HBV': HBV_codes,
  'HCV': HCV_codes,
  'HDV': HDV_codes,
  'HEV': HEV_codes,
  'hidradenitis_suppurativa': hidradenitis_codes,
  'history_bariatric': bariatric_codes,
  'history_transplant': tx_codes,
  'HIV': hiv_codes,
  'HIV_related_sclerosing_cholangitis': HIV_related_sclerosing_cholangitis_codes,
  'huntington' : huntington_codes,
  'hpylori' : hpylori_codes,
  'hypercoagulability': hypercoagulability_codes,
  'hyperlipidemia' : hld_codes,
  'hypertension': hypertension_codes,
  'hypertension_pregnancy_related': hypertension_pregnancy_related_codes,
  'hypothyroidism' : hypothyroidism_codes,
  'immunodeficiency' : immune_codes,
  'ipf':ipf_codes,
  'ibd' : ibd_codes,
  'inflammation_of_sacroiliac_joint' : inflammation_of_sacroiliac_joint_codes,
  'influenza': influenza_codes,
  'infectious_arthritis' : inf_arth_codes,
  'ibs' : ibs_codes,
  'other_ibd': other_ibd_codes,
  'ulcerative_colitis': ulcerative_colitis_codes,
  'insomnia': insomnia_codes,
  'kidney_cancer': kidney_cancer_codes,
  'kidney_dialysis' : dialysis_codes,
  'leukemia': leukemia_codes,
  'lewy' : lewy_disease_codes,
  'liver_cancer': liver_cancer_codes,
  'lymphoma_hodgkin': lymphoma_hodgkin_codes,
  'lymphoma_non_hodgkin': lymphoma_nonhodgkin_codes,
  'limited_sclerosis': limited_sclerosis_codes,
  'lung_cancer': lung_cancer_codes,
  'lupus': sle_codes,
  'major_depression' : major_depression_codes,
  'malabsorption': malabsorption_codes,
  'malignant_neoplastic_disease': malignant_neoplastic_disease_codes,
  'malignant_neoplastic_disease_noBSC_noSCC': malignant_neoplastic_disease_noBSC_noSCC_codes,
  'marijuana' : marijuana_codes,
  'mar': mar_codes,
  'melanoma': melanoma_codes,
  'multiple_sclerosis': multiple_sclerosis_codes,
  'multicentric_reticulohistiocytosis': multicentric_reticulohistiocytosis_codes,
  'myastenia': myastenia_codes,
  'mycosis': mycosis_codes,
  'mycosis_fungoides': mycosis_fungoides_codes,
  'myelodysplastic' : mds_codes,
  'myocardial_infarction': myocardial_infarction_codes,
  'NAFLD': NAFLD_codes,
  'nausea_vomiting' : nv_codes,
  'NASH': NASH_codes,
  'neonatal_sclerosing_cholangitis': neonatal_sclerosing_cholangitis_codes,
  'neutropenia': neutropenia_codes,
  'normal_pressure_hydrocephalus' : nph_codes,
  'obesity': obesity_codes,
  'obstructive_sleep_apnea' : osa_codes,
  'opioid_dependence' : opioid_codes,
  'osteoarthritis': osteoarthritis_codes,
  'osteoporosis': osteoporosis_codes,
  'osteosarcoma': osteosarcoma_codes,
  'pancreatitis' : pancreatitis_codes,
  'pancreatic_cancer': pancreatic_cancer_codes,
  'patient_immunocompromised' : pt_immuno_codes,
  'peptic_ulcer' : pud_codes,
  'pemphigus_vulgaris': pv_codes,
  'peripheral_arterial_disease': peripheral_arterial_disease_codes,
  'peripheral_vascular_disease': peripheral_vascular_disease_codes,
  'peripheral_spondyloarthritis' : peripheral_spondyloarthritis_codes,
  'pneumonia': pneumonia_codes,
  'polymyositis': polymyositis_codes,
  'polyp' : polyp_codes,
  'post_anoxic_coma' :post_anoxic_codes,
  'post_cardiorespiratory_arrest_coma': post_crf_coma_codes,
  'pregnancy_tubal_ectopic': pregnancy_tubal_codes,
  'preeclampsia': preeclampsia_codes,
  'perivenous_encephalomyelitis': perivenous_encephalomyelitis_codes,
  'protein_calorie_malnutrition': protein_calorie_malnutrition_codes,
  'primary_sclerosing_cholangitis': primary_sclerosing_cholangitis_codes,
  'secondary_sclerosing_cholangitis': secondary_sclerosing_cholangitis_codes,
  'primary_biliary_cholangitis': primary_biliary_cholangitis_codes,
  'prostate_cancer': prostate_cancer_codes,
  'psoriatic_arthritis': psoriatic_arthritis_codes,
  'psoriasis' : psoriasis_codes,
  'psoriasis_no_exclude' : psoriasis_codes,
  'pulmonary_embolism' : pe_codes,
  'renal_impairment':renal_impairment_codes,
  'renal_insufficiency': renal_insufficiency_codes,
  'respiratory_distress': respiratory_distress_codes,
  'rheumatoid_arthritis': rheumatoid_arthritis_codes,
  'sarcoidosis': sarcoidosis_codes,
  'schizophrenia' : schizophrenia_codes,
  'seizure': seizure_codes,
  'senile_degeneratiom_brain': senile_codes,
  'sepsis': sepsis_codes,
  'stroke': stroke_codes,
  'sirs': sirs_codes,
  'shock': shock_codes,
  'spinal_enthesopathy': spinal_enthesopathy_codes,
  'spondyloarthritis': spondyloarthritis_codes,
  'systemic_lupus' : sle_codes,
  'sympathetic_ophthalmia': sympathetic_ophthalmia_codes,
  'systemic_sclerosis': scleroderma_codes,
  'sjogren_syndrome': sjogren_syndrome_codes,
  'tachycardia': tachycardia_codes,
  'thyroid_cancer': thyroid_cancer_codes,
  'tobacco' : tobacco_codes,
  'turner_syndrome': turner_syndrome_codes,
  'transplantation_liver': transplantation_liver_codes,
  'transverse_myelitis': transverse_myelitis_codes,
  'triple_negative' : triple_codes,
  'traumatic_brain_injury': traumatic_brain_injury_codes,
  'uveitis': uveitis_codes,
  'vasculitis': vasculitis_codes,
  'other_codes_and_types_of_autoimmune_vasculitis': other_codes_and_types_of_autoimmune_vasculitis_codes,
  'urinary_tract_infection': urinary_tract_infection_codes,
  'wernicke_korsakoff': wk_infection_codes
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
